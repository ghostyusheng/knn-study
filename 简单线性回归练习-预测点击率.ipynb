# %%
import numpy as np
import matplotlib.pyplot as plt
# %run linear/simple_linear_regression.py

# %%
y = np.array([137.50,134.41,134.44
,
136.16
,
137.50
,
142.15
,
146.22
,
143.88
,
139.63
,
135.50
,
140.41
,
140.19
,
141.74
,
140.77
,
141.04
,
139.90
,
142.39
,
141.14
,
140.61
,
142.63
,
143.60
,
142.31
,
142.83
,
142.94
,
141.40
,
142.46
,
145.54
 
])

# %%
x = np.array([
    486223 
,
417530 
,
435470 
,
401470 
,
412752 
,
452508 
,
573190 
,
509030 
,
383075 
,
418660 
,
427646 
,
522770 
,
737052 
,
637164 
,
515412 
,
398934 
,
424251 
,
427264 
,
498296 
,
528478 
,
652498 
,
575631 
,
428018 
,
450526 
,
453081 
,
508236 
,
537228 

])

# %%
plt.scatter(x, y)

# %%
reg = SimpleLinearRegression1()
reg.fit(x, y)
y_hat = reg.a_ * x + reg.b_

# %%
plt.title('APP: search unique keyword count - search click rate')
plt.scatter(x, y)
plt.plot(x, y_hat, color='r')

# %%
date_index = np.array(list(enumerate(list(y))))[...,0]

# %%
plt.title('APP: 2019_09_* - search click rate')
plt.scatter(date_index, y)

reg = SimpleLinearRegression1()
reg.fit(date_index, y)
y_hat = reg.a_ * date_index + reg.b_

plt.plot(date_index, y_hat, color='r')

# %%
# 计算topic的点击率

# %%
# Topic 点击率
y = np.array([193.57,207.96,204.68,212.35,212.83,201.12,187.55,196.69,206.98,194.81,202.49,190.57,172.49,181.84,189.83,203.43,195.66,184.55,179.92,167.91,153.44,165.69,179.42,175.58,179.36,160.61,162.02
])
x = np.array(list(enumerate(y)), dtype=np.int16)[...,0]
plt.scatter(x, y)
reg = SimpleLinearRegression1()
reg.fit(x, y)
y_hat = reg.a_ * x + reg.b_
plt.plot(x, y_hat, color='r')
